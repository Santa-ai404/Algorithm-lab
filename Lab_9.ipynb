# %% [markdown]
# <a href="https://colab.research.google.com/github/Santa-ai404/Algorithm-lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
import heapq

def dijkstra(graph, start, end=None):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    distances[start] = 0
    pq = [(0, start)]

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    if end:
        path = []
        node = end
        while node is not None:
            path.insert(0, node)
            node = previous[node]
        return distances[end], path
    return distances, previous

# %%
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}
    neighbors = int(input(f"Enter number of neighbors for {node}: "))
    for j in range(neighbors):
        neighbor = input(f"  Neighbor {j+1} of {node}: ")
        weight = int(input(f"  Weight from {node} to {neighbor}: "))
        graph[node][neighbor] = weight

# Add two more nodes manually
graph['E'] = {'D': 4, 'F': 6}
graph['F'] = {'E': 6, 'C': 7}

# Test with different source nodes
source = input("Enter source node: ")
target = input("Enter target node: ")

distance, path = dijkstra(graph, source, target)
print(f"Shortest path from {source} to {target}: {' -> '.join(path)}")
print(f"Total distance: {distance}")
# Out:
# Enter number of nodes: 3
# Enter node 1 name: 1
# Enter number of neighbors for 1: 2
#   Neighbor 1 of 1: 2
#   Weight from 1 to 2: 5
#   Neighbor 2 of 1: 2
#   Weight from 1 to 2: 5
# Enter node 2 name: 2
# Enter number of neighbors for 2: 3
#   Neighbor 1 of 2: 3
#   Weight from 2 to 3: 5
#   Neighbor 2 of 2: 1
#   Weight from 2 to 1: 6
#   Neighbor 3 of 2: 2
#   Weight from 2 to 2: 2
# Enter node 3 name: 3
# Enter number of neighbors for 3: 2
#   Neighbor 1 of 3: 1
#   Weight from 3 to 1: 3
#   Neighbor 2 of 3: 3
#   Weight from 3 to 3: 4
# Enter source node: 1
# Enter target node: 3
# Shortest path from 1 to 3: 1 -> 2 -> 3
# Total distance: 10

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
